# %% [markdown]
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
from scipy. stats import uniform
import numpy as np
import scipy
import sympy
from scipy.stats import laplace

# %%
arr=np.random.uniform(200,800,600)
arr
# Out:
# array([212.68359152, 466.53120909, 698.88405251, 436.89526937,
#        482.3970261 , 576.10046622, 264.03673566, 609.21332651,
#        544.44464838, 343.48195915, 592.85508488, 275.91983882,
#        351.05975792, 293.4958915 , 508.70565308, 570.98801291,
#        417.31704039, 579.3492192 , 334.03536483, 204.63831976,
#        608.13285511, 269.36295564, 685.95864152, 736.31529297,
#        633.20981726, 557.8724462 , 472.13838863, 733.50403981,
#        298.25736619, 495.53971336, 584.06359949, 479.37956033,
#        767.78597331, 239.55568769, 527.0519902 , 405.50202953,
#        569.60354794, 571.75908363, 584.97723022, 496.33606629,
#        285.31590568, 719.02952715, 280.40114861, 328.67771894,
#        390.09480766, 219.25846153, 355.4613441 , 295.52318804,
#        244.8624723 , 544.62632412, 563.96028862, 545.69495806,
#        768.93204269, 232.14952521, 366.08303477, 668.3967695 ,
#        531.58763762, 726.23532472, 670.85938215, 657.35961568,
# ...

# %%
np.mean(arr)
# Out:
# 500.2368637890027

# %%
np.var(arr)
# Out:
# 28997.400903313166

# %% [markdown]
# M(x)=(a+b)/2

# %%
(200+800)/2
# Out:
# 500.0

# %% [markdown]
# $$P=\frac{(b-a)^2}{12}$$

# %%
P=((800-200)**2)/12
P
# Out:
# 30000.0

# %% [markdown]
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# 0.2=((0.5+b)^2)/12

# %% [markdown]
# $$P=\frac{(b-a)^2}{12}$$

# %%
a=0.5
c=np.sqrt(2.4)
c
# Out:
# 1.5491933384829668

# %%
b=0.5+np.sqrt(2.4)
b
# Out:
# 2.049193338482967

# %%
M=(a+b)/2

# %%
M
# Out:
# 1.2745966692414834

# %% [markdown]
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2pi))) * exp((-(x+2)**2) / 32)
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
from sympy import *
from sympy import Symbol

# %%
x, y, t = symbols("x, y, t")

# %%
fx = (1/(4*sqrt(2*pi)))*exp((-(x+2)**2) / 32)
fx
# Out:
# sqrt(2)*exp(-(x + 2)**2/32)/(8*sqrt(pi))

# %%
sigma=4
a=-2 #M(x)

# %%
dx=sigma**2
dx
# Out:
# 16

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.
#
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# $$P(\alpha<X<\beta) = \Phi\left(\frac{\beta- a}{\sigma}\right) - \Phi\left(\frac{\alpha-a}{\sigma}\right)$$
# где $$\Phi(x)$$ - функция Лапласа

# %%
x=(182-174)/8
z0=1-scipy.stats.norm.cdf(x)
z0
# Out:
# 0.15865525393145707

# %%
x1=(190-174)/8
z1=1-scipy.stats.norm.cdf(x1)
z1
# Out:
# 0.02275013194817921

# %%
zz1=(166-174)/8
zz2=2

# %%
pp=scipy.stats.norm.cdf(zz2)-scipy.stats.norm.cdf(zz1)
pp
# Out:
# 0.8185946141203637

# %%
zzz1=-1
zzz2=1
scipy.stats.norm.cdf(zzz2)-scipy.stats.norm.cdf(zzz1)
# Out:
# 0.6826894921370859

# %%
zzzz1=(158-174)/8
zzzz2=2
scipy.stats.norm.cdf(zzzz2)-scipy.stats.norm.cdf(zzzz1)
# Out:
# 0.9544997361036416

# %%
zzzzz1=(150-174)/8
zzzzz2=(190-174)/8
1-scipy.stats.norm.cdf(zzzzz2)+scipy.stats.norm.cdf(zzzzz1)
# Out:
# 0.0241000299798093

# %%
zzzzzz1=(198-174)/8
zzzzzz2=(150-174)/8
zzzzzz1,zzzzzz2,1-(scipy.stats.norm.cdf(zzzzzz1)-scipy.stats.norm.cdf(zzzzzz2))
# Out:
# (3.0, -3.0, 0.002699796063260207)

# %%
z1a=(166-174)/8
scipy.stats.norm.cdf(z1a)
# Out:
# 0.15865525393145707

# %% [markdown]
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# M(X)=178=m
# D(X)=sigma**2  25=> sigma=5

# %%
Z=(190-178)/5
Z
# Out:
# 2.4
